# %%
import kneed
import numpy as np
import pandas as pd
import sklearn.preprocessing
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram
from sklearn import cluster

data = pd.read_csv('Country-data.csv')
data
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp
# 0         9.44        56.2       5.82    553
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     167 non-null    object
#  1   child_mort  167 non-null    float64
#  2   exports     167 non-null    float64
#  3   health      167 non-null    float64
#  4   imports     167 non-null    float64
#  5   income      167 non-null    int64
#  6   inflation   167 non-null    float64
#  7   life_expec  167 non-null    float64
#  8   total_fer   167 non-null    float64
#  9   gdpp        167 non-null    int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 13.2+ KB

# %%
data.isnull().sum()
# Out:
# country       0
# child_mort    0
# exports       0
# health        0
# imports       0
# income        0
# inflation     0
# life_expec    0
# total_fer     0
# gdpp          0
# dtype: int64

# %%
data.describe()
# Out:
#        child_mort     exports      health     imports         income  \
# count  167.000000  167.000000  167.000000  167.000000     167.000000
# mean    38.270060   41.108976    6.815689   46.890215   17144.688623
# std     40.328931   27.412010    2.746837   24.209589   19278.067698
# min      2.600000    0.109000    1.810000    0.065900     609.000000
# 25%      8.250000   23.800000    4.920000   30.200000    3355.000000
# 50%     19.300000   35.000000    6.320000   43.300000    9960.000000
# 75%     62.100000   51.350000    8.600000   58.750000   22800.000000
# max    208.000000  200.000000   17.900000  174.000000  125000.000000
#
#         inflation  life_expec   total_fer           gdpp
# count  167.000000  167.000000  167.000000     167.000000
# mean     7.781832   70.555689    2.947964   12964.155689
# std     10.570704    8.893172    1.513848   18328.704809
# min     -4.210000   32.100000    1.150000     231.000000
# 25%      1.810000   65.300000    1.795000    1330.000000
# ...

# %%
c_d = data[data.gdpp < data.gdpp.quantile(0.9)]
c_d
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp
# 0         9.44        56.2       5.82    553
# ...

# %%
scaler = sklearn.preprocessing.MinMaxScaler()

nocountries_data = c_d.drop(["country"], axis=1)
normalized_data = scaler.fit_transform(nocountries_data)
normalized_data = pd.DataFrame(normalized_data, columns=nocountries_data.columns,
                                   index=nocountries_data.index)

# %%
data_selection = normalized_data[["income", "gdpp", "child_mort"]]
data_selection
# Out:
#        income      gdpp  child_mort
# 0    0.012514  0.007746    0.424805
# 1    0.116526  0.092834    0.065430
# 2    0.153655  0.101734    0.117676
# 3    0.066145  0.079362    0.565430
# 4    0.231164  0.287931    0.034668
# ..        ...       ...         ...
# 162  0.029266  0.065890    0.126953
# 163  0.198660  0.319204    0.067871
# 164  0.048518  0.025957    0.098145
# 165  0.048393  0.025957    0.259277
# 166  0.033391  0.029565    0.390137
#
# [150 rows x 3 columns]

# %%
data_dbscan = sklearn.cluster.DBSCAN(eps=0.20, min_samples=30).fit_predict(data_selection)
plt.scatter(data_selection["income"], data_selection["gdpp"], c=data_dbscan, s=50)
plt.show()
plt.scatter(data_selection["child_mort"], data_selection["gdpp"], c=data_dbscan, s=50)
plt.show()
plt.scatter(data_selection["income"], data_selection["child_mort"], c=data_dbscan, s=50)
plt.show()

# %%
kmeans_kwargs = {
    "init": "random",
    "n_init": 10,
    "max_iter": 300,
    "random_state": 42,
}

# A list holds the SSE values for each k
sse = []
for k in range(1, 11):
    kmeans = cluster.KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(data_selection)
    sse.append(kmeans.inertia_)

plt.style.use("fivethirtyeight")
plt.plot(range(1, 11), sse)
plt.xticks(range(1, 11))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.show()
# Out:
# c:\Users\podol\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
kl = kneed.KneeLocator(range(1, 11), sse, curve="convex", direction="decreasing")
num_of_clusters = kl.elbow
num_of_clusters
# Out:
# 3

# %%
kmeans_labels = cluster.KMeans(num_of_clusters).fit_predict(data_selection)
plt.scatter(data_selection["income"], data_selection["gdpp"], c=kmeans_labels,
            s=50, cmap='viridis')
plt.show()
plt.scatter(data_selection["child_mort"], data_selection["gdpp"], c=kmeans_labels,
            s=50, cmap='viridis')
plt.show()
plt.scatter(data_selection["income"], data_selection["child_mort"], c=kmeans_labels,
            s=50, cmap='viridis')
plt.show()

# %%
meanshift_labels = cluster.MeanShift().fit_predict(data_selection)
plt.scatter(data_selection["income"], data_selection["gdpp"], c=meanshift_labels,
            s=50, cmap='viridis')
plt.show()
plt.scatter(data_selection["child_mort"], data_selection["gdpp"], c=meanshift_labels,
            s=50, cmap='viridis')
plt.show()
plt.scatter(data_selection["income"], data_selection["child_mort"], c=meanshift_labels,
            s=50, cmap='viridis')
plt.show()

# %%
clustered_income = data_selection.copy()
clustered_income["cluster"] = meanshift_labels
clustered_income
# Out:
#        income      gdpp  child_mort  cluster
# 0    0.012514  0.007746    0.424805        0
# 1    0.116526  0.092834    0.065430        0
# 2    0.153655  0.101734    0.117676        0
# 3    0.066145  0.079362    0.565430        0
# 4    0.231164  0.287931    0.034668        0
# ..        ...       ...         ...      ...
# 162  0.029266  0.065890    0.126953        0
# 163  0.198660  0.319204    0.067871        0
# 164  0.048518  0.025957    0.098145        0
# 165  0.048393  0.025957    0.259277        0
# 166  0.033391  0.029565    0.390137        0
#
# [150 rows x 4 columns]

# %%
coeficient = np.array([4, 3, 5])

cluster_grouped = clustered_income.groupby(["cluster"], as_index=False).mean()
cluster_grouped["score"] = cluster_grouped.apply(lambda row: 1 / np.dot(row.drop("cluster").to_numpy(), coeficient), axis=1)
cluster_grouped.sort_values(by=["score"])
# Out:
#    cluster    income      gdpp  child_mort     score
# 2        2  0.785601  0.900166    0.026001  0.167423
# 3        3  0.112244  0.109060    0.752197  0.220403
# 1        1  0.378226  0.581200    0.018777  0.298473
# 0        0  0.094181  0.093426    0.208154  0.589007

# %%
clustered_income["country"] = c_d["country"]
clustered_income[clustered_income["cluster"] == 3]
# Out:
#        income      gdpp  child_mort  cluster            country
# 32   0.016514  0.016022    0.716797        3               Chad
# 49   0.413684  0.405807    0.526367        3  Equatorial Guinea
# 66   0.011139  0.010368    1.000000        3              Haiti
# 132  0.007638  0.004041    0.765625        3       Sierra Leone

# %%
clustered_income[clustered_income["cluster"] == 2]
# Out:
#        income      gdpp  child_mort  cluster               country
# 23   1.000000  0.843633    0.035645        2                Brunei
# 58   0.497443  1.000000    0.004883        2               Germany
# 82   0.932492  0.920614    0.037109        2                Kuwait
# 157  0.712468  0.836417    0.026367        2  United Arab Emirates
